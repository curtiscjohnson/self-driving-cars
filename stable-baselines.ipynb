# %% [markdown]
# # Working DQN Example on CartPole-v1 Environment

# %%
import gym
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
import wandb
from wandb.integration.sb3 import WandbCallback


config = {
  "n_timesteps": 5e4,
  "policy": 'MlpPolicy',
  "learning_rate": 2.3e-3,
  "batch_size": 64,
  "buffer_size": 100000,
  "learning_starts": 1000,
  "gamma": 0.99,
  "target_update_interval": 10,
  "train_freq": 256,
  "gradient_steps": 128,
  "exploration_fraction": 0.16,
  "exploration_final_eps": 0.04,
  "policy_kwargs": dict(net_arch=[256, 256]),
  "seed":42,
  "env_name":"CartPole-v1",
}

run = wandb.init(
    project="sb3",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


def make_env():
    env = gym.make(config["env_name"])
    env = Monitor(env)  # record stats such as returns
    return env


env = DummyVecEnv([make_env])
env = VecVideoRecorder(
    env,
    f"videos/{run.id}",
    record_video_trigger=lambda x: x % 2000 == 0,
    video_length=200
)


model = DQN(
    config["policy"],
    env,
    learning_rate=config["learning_rate"],
    batch_size=config["batch_size"],
    buffer_size=config["buffer_size"],
    learning_starts=config["learning_starts"],
    gamma=config["gamma"],
    target_update_interval=config["target_update_interval"],
    train_freq=config["train_freq"],
    gradient_steps=config["gradient_steps"],
    exploration_fraction=config["exploration_fraction"],
    exploration_final_eps=config["exploration_final_eps"],
    policy_kwargs=config["policy_kwargs"],
    tensorboard_log=f"runs/{run.id}",
    verbose=1,
    seed=config["seed"]
)

model.learn(
    total_timesteps=config["n_timesteps"],
    callback=WandbCallback(
        gradient_save_freq=100,
        model_save_path=f"models/{run.id}",
        verbose=0,
    ),
)
run.finish()
# Out:
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/home/curtis/classes/self-driving-cars/wandb/run-20230303_121456-rbu3wujf</code>
# Syncing run <strong><a href='https://wandb.ai/curtiscjohnson/sb3/runs/rbu3wujf' target="_blank">misty-waterfall-18</a></strong> to <a href='https://wandb.ai/curtiscjohnson/sb3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/curtiscjohnson/sb3' target="_blank">https://wandb.ai/curtiscjohnson/sb3</a>
#  View run at <a href='https://wandb.ai/curtiscjohnson/sb3/runs/rbu3wujf' target="_blank">https://wandb.ai/curtiscjohnson/sb3/runs/rbu3wujf</a>
# Using cuda device
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to runs/rbu3wujf/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 45       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 51       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 144      |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-0-to-step-200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 59       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 222      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 85       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 101      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 119      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 450      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 150      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 568      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 170      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 644      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 190      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 720      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 206      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 781      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 241      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 916      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 264      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 274      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1103     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0128   |
# |    n_updates        | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 287      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 299      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 306      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1300     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0393   |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 319      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 332      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 351      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 360      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1619     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0632   |
# |    n_updates        | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 375      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 381      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1798     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0713   |
# |    n_updates        | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 392      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 412      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 393      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 272      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2176     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0701   |
# |    n_updates        | 640      |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-2000-to-step-2200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 269      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 271      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2346     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0838   |
# |    n_updates        | 768      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 284      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 291      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2590     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0819   |
# |    n_updates        | 896      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 309      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 312      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2853     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0968   |
# |    n_updates        | 1024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 331      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 344      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3225     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.0934   |
# |    n_updates        | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 351      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3365     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.116    |
# |    n_updates        | 1280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.7     |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 372      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.5     |
# |    ep_rew_mean      | 27.5     |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 381      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3754     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.129    |
# |    n_updates        | 1408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 28.7     |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 394      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3974     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.124    |
# |    n_updates        | 1536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.501    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 318      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 4161     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.134    |
# |    n_updates        | 1664     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-4000-to-step-4200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.1     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 325      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4622     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.149    |
# |    n_updates        | 1920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 37.1     |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 345      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 5008     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.179    |
# |    n_updates        | 2048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | 40.5     |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 360      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 5407     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.184    |
# |    n_updates        | 2304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.4     |
# |    ep_rew_mean      | 41.4     |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 369      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 5553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.3     |
# |    ep_rew_mean      | 41.3     |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 374      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 5630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.295    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 383      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 5872     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.223    |
# |    n_updates        | 2432     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-6000-to-step-6200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.9     |
# |    ep_rew_mean      | 46.9     |
# |    exploration_rate | 0.235    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 331      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 6379     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.241    |
# |    n_updates        | 2688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.1     |
# |    ep_rew_mean      | 50.1     |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 345      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 6807     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.256    |
# |    n_updates        | 2944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.2     |
# |    ep_rew_mean      | 50.2     |
# |    exploration_rate | 0.176    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 348      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 6869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 53.1     |
# |    exploration_rate | 0.128    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 359      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 7269     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.231    |
# |    n_updates        | 3200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.5     |
# |    ep_rew_mean      | 55.5     |
# |    exploration_rate | 0.0917   |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 369      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 7569     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.293    |
# |    n_updates        | 3328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.5     |
# |    ep_rew_mean      | 59.5     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 350      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 8128     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.349    |
# |    n_updates        | 3584     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-8000-to-step-8200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.9     |
# |    ep_rew_mean      | 60.9     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 338      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 8357     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.317    |
# |    n_updates        | 3712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.6     |
# |    ep_rew_mean      | 63.6     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 345      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 8705     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.304    |
# |    n_updates        | 3968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | 68.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 362      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 9344     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.289    |
# |    n_updates        | 4224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.8     |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 370      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 9665     |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.289    |
# |    n_updates        | 4352     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-10000-to-step-10200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.3     |
# |    ep_rew_mean      | 75.3     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 339      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 10284    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.276    |
# |    n_updates        | 4736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.4     |
# |    ep_rew_mean      | 78.4     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 349      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 10692    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.29     |
# |    n_updates        | 4864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | 82.2     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 361      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 11258    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.317    |
# |    n_updates        | 5120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 367      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 11632    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.311    |
# |    n_updates        | 5376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.8     |
# |    ep_rew_mean      | 85.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 374      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 11948    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.302    |
# |    n_updates        | 5504     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-12000-to-step-12200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | 87.7     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 344      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 12347    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.299    |
# |    n_updates        | 5760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 90       |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 353      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 12754    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.339    |
# |    n_updates        | 5888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | 91.3     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 357      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 13109    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.353    |
# |    n_updates        | 6144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | 92.6     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 363      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 13425    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.337    |
# |    n_updates        | 6272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | 91.5     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 370      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 13769    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.338    |
# |    n_updates        | 6400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | 90.1     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 369      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 14022    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.446    |
# |    n_updates        | 6528     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-14000-to-step-14200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | 89.2     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 348      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 14326    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.385    |
# |    n_updates        | 6656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | 91.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 353      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 14737    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.369    |
# |    n_updates        | 6912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | 93.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 357      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 15007    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.523    |
# |    n_updates        | 7040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 95.5     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 363      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 15425    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.498    |
# |    n_updates        | 7296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | 93.3     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 367      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 15707    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.399    |
# |    n_updates        | 7424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | 91.9     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 372      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 15996    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.349    |
# |    n_updates        | 7552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | 93       |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 350      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 16169    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.45     |
# |    n_updates        | 7680     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-16000-to-step-16200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | 92.7     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 352      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 16541    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.477    |
# |    n_updates        | 7808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | 92.3     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 355      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 16799    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.491    |
# |    n_updates        | 7936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | 89.7     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 359      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 17097    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.439    |
# |    n_updates        | 8064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | 91.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 364      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 17532    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.392    |
# |    n_updates        | 8320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | 91.9     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 369      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 17895    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.464    |
# |    n_updates        | 8448     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-18000-to-step-18200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | 89.5     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 349      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 18298    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.469    |
# |    n_updates        | 8704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | 90.6     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 354      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 18729    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.406    |
# |    n_updates        | 8960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.4     |
# |    ep_rew_mean      | 86.4     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 357      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 18923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | 86.2     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 360      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 19313    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.412    |
# |    n_updates        | 9216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | 82       |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 363      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 19455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | 80.7     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 366      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 19705    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.508    |
# |    n_updates        | 9344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.7     |
# |    ep_rew_mean      | 81.7     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 356      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 20119    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.498    |
# |    n_updates        | 9600     |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-20000-to-step-20200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.3     |
# |    ep_rew_mean      | 82.3     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 352      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 20579    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.427    |
# |    n_updates        | 9856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | 82.2     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 357      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 20974    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.345    |
# |    n_updates        | 9984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.8     |
# |    ep_rew_mean      | 83.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 363      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 21488    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.409    |
# |    n_updates        | 10240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83       |
# |    ep_rew_mean      | 83       |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 365      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 21726    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.466    |
# |    n_updates        | 10368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.9     |
# |    ep_rew_mean      | 81.9     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 368      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 21963    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.404    |
# |    n_updates        | 10496    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-22000-to-step-22200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.3     |
# |    ep_rew_mean      | 82.3     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 351      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 22248    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.396    |
# |    n_updates        | 10624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.1     |
# |    ep_rew_mean      | 85.1     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 356      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 22839    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.452    |
# |    n_updates        | 11008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | 86.2     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 361      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 23354    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.375    |
# |    n_updates        | 11264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 88       |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 365      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 23812    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.426    |
# |    n_updates        | 11520    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-24000-to-step-24200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | 89.8     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 352      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 24407    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.434    |
# |    n_updates        | 11776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | 97.3     |
# |    exploration_rate | 0.04     |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 366      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 29911    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.452    |
# |    n_updates        | 14464    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-30000-to-step-30200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 355      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 30487    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.529    |
# |    n_updates        | 14848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 361      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 31295    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.471    |
# |    n_updates        | 15232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 361      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 31370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 362      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 31465    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-32000-to-step-32200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 354      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 32232    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.551    |
# |    n_updates        | 15616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 355      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 34186    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.606    |
# |    n_updates        | 16640    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-34000-to-step-34200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 362      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 36069    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.548    |
# |    n_updates        | 17536    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-36000-to-step-36200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 359      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 36843    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.503    |
# |    n_updates        | 17920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 364      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 37761    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.542    |
# |    n_updates        | 18432    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-38000-to-step-38200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 356      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 38408    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.565    |
# |    n_updates        | 18816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 360      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 39188    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.485    |
# |    n_updates        | 19200    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-40000-to-step-40200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 356      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 40302    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.51     |
# |    n_updates        | 19712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 358      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 40588    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.526    |
# |    n_updates        | 19840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 358      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 40768    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.629    |
# |    n_updates        | 19968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 360      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 42121    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.508    |
# |    n_updates        | 20608    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-42000-to-step-42200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 359      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 42810    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.414    |
# |    n_updates        | 20992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 360      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 42975    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-44000-to-step-44200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 357      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 44418    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.457    |
# |    n_updates        | 21760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 358      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 44563    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.539    |
# |    n_updates        | 21888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 361      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 45194    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.547    |
# |    n_updates        | 22144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 362      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 45255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 362      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 45355    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.497    |
# |    n_updates        | 22272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 363      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 45563    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-46000-to-step-46200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 361      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 47190    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.639    |
# |    n_updates        | 23168    |
# ----------------------------------
# Saving video to /home/curtis/classes/self-driving-cars/videos/rbu3wujf/rl-video-step-48000-to-step-48200.mp4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 360      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 49190    |
# | train/              |          |
# |    learning_rate    | 0.0023   |
# |    loss             | 0.613    |
# |    n_updates        | 24192    |
# ----------------------------------
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▇▇▇▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▃▄▄▄▄▄▄▄▄▃▄▃▄▄▅▅▅▇▇██▇█</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▃▄▄▄▄▄▄▄▄▃▄▃▄▄▅▅▅▇▇██▇█</td></tr><tr><td>rollout/exploration_rate</td><td>███▇▇▇▇▆▆▆▅▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▁▂▃▄▆▇▇█▆▆▇█▇█▇▇▇█▇▇█▇█▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▁▂▂▂▂▂▃▃▄▄▄▄▄▄▅▅▆▇▅▆▆▆▅▆▅▆▅▆▆▅▇▇▇▆▇▇▇▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>49190</td></tr><tr><td>rollout/ep_len_mean</td><td>192.78999</td></tr><tr><td>rollout/ep_rew_mean</td><td>192.78999</td></tr><tr><td>rollout/exploration_rate</td><td>0.04</td></tr><tr><td>time/fps</td><td>360.0</td></tr><tr><td>train/learning_rate</td><td>0.0023</td></tr><tr><td>train/loss</td><td>0.61324</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misty-waterfall-18</strong> at: <a href='https://wandb.ai/curtiscjohnson/sb3/runs/rbu3wujf' target="_blank">https://wandb.ai/curtiscjohnson/sb3/runs/rbu3wujf</a><br/>Synced 5 W&B file(s), 25 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230303_121456-rbu3wujf/logs</code>
